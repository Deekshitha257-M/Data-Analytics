# %%
a=2
print(a)
# Out:
# 2

# %%
x=10
y="DEE"
print(x)
print(y)
# Out:
# 10
# DEE

# %%
x=3
x="Sonnu"
x=8
print(x)
# Out:
# 8

# %%
x=str(3)
y=int(3)
z=float(3)
print(x)
print(y)
print(z)
# Out:
# 3
# 3
# 3.0

# %%
x=5
y="john"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=4
A="Sally"
print(a)
print(A)
# Out:
# 4
# Sally

# %%
x,y,z="Orange","Banana","Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x=y=z="Apple"
print(x)
print(y)
print(z)
# Out:
# Apple
# Apple
# Apple

# %%
fruits=["Apple","banana","cherry"]
x,y,z=fruits
print(x)
print(y)
print(z)
# Out:
# Apple
# banana
# cherry

# %%
x="Python"
y="is"
z="awesome"
print(x,y,z)
# Out:
# Python is awesome

# %%
x=5
print(type(x))
# Out:
# <class 'int'>

# %%
x=1
y=2.3
z=1j
print(x)
print(y)
print(z)
# Out:
# 1
# 2.3
# 1j

# %%
x=1
y-3789386265738279
z=275789
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %%
x=1
y=258997852657
z=-3221134
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
x=1.10
y=1.0
z=-34.32
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>

# %%
x=5+2j
y=5j
z=-5j
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>

# %%
x=1
y=2.8
z=1j
a=float(x)
b=int(y)
c=complex(x)
print(a)
print(b)
print(c)
# Out:
# 1.0
# 2
# (1+0j)

# %%
x=int(1)
y=int(2.4)
z=int("3")
print(x)
print(y)
print(z)
# Out:
# 1
# 2
# 3

# %%
x=float(1)
y=float(2.4)
z=float("3")
w=float(4.2)
print(x)
print(y)
print(z)
print(w)
# Out:
# 1.0
# 2.4
# 3.0
# 4.2

# %%
x=str("s1")
y=str(2)
z=str(3.0)
print(x)
print(y)
print(z)
# Out:
# s1
# 2
# 3.0

# %%
a="Hellp"
print(a)
# Out:
# Hellp

# %%
a="""hello.world"""
print(a)
# Out:
# hello.world

# %%
a="Hello, world!"
print(a[1])
# Out:
# e

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
a="Hello,World!"
print(len(a))
# Out:
# 12

# %%
txt="The best things in life are free!"
print("free" in txt)
# Out:
# True

# %%
txt="The best things in life are free!"
if"free"in txt:
  print("Yes,'free'is present")
# Out:
# Yes,'free'is present

# %%
txt="The world full of lesson!"
print("expensive" not in txt)
# Out:
# True

# %%
b="Hello, World!"
print(b[2:5])
# Out:
# llo

# %%
a=b="the world is beautiful!"
print(b[:5])
print(b[2:])
print(b[-5:-2])
print(a.upper())
print(a.lower())
# Out:
# the w
# e world is beautiful!
# ifu
# THE WORLD IS BEAUTIFUL!
# the world is beautiful!

# %%
a="Hello,world "
print(len(a))
print(a.strip())
print(a.replace("H","N"))
print(a.split(","))
# Out:
# 12
# Hello,world
# Nello,world
# ['Hello', 'world ']

# %%
a="Hello"
b="World"
c=a+b
print(c)
# Out:
# HelloWorld

# %%
print(10>8)
print(10==9)
print(10<9)
# Out:
# True
# False
# False

# %%
a=200
b=22
if b>a:
  print("B is greater then A")
else:
  print("B is not greater than A")
# Out:
# B is not greater than A

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
mylist=["apple","banana","cherry"]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=["apple","banana","cherry"]
print(len(thislist))
# Out:
# 3

# %%
thislist=["apple","banana","cherry","apple"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple']

# %%
thislist=["apple","banana","cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
list1=["apple","banana","cherry"]
list2=[1,2,3,4,5]
list3=[True,False,False]
print(list1)
print(list2)
print(list3)
# Out:
# ['apple', 'banana', 'cherry']
# [1, 2, 3, 4, 5]
# [True, False, False]

# %%
list1=["abc",32,True,25,"male"]
print(list1)
# Out:
# ['abc', 32, True, 25, 'male']

# %%
mylist=["apple","banana","cherry"]
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist=("apple","banana","cherry","orange","kiwi","melon","mango")
print(thislist[1])
print(thislist[-1])
print(thislist[2:5])
print(thislist[:4])
print(thislist[-4:-1])
# Out:
# banana
# mango
# ('cherry', 'orange', 'kiwi')
# ('apple', 'banana', 'cherry', 'orange')
# ('orange', 'kiwi', 'melon')

# %%
thislist=("apple","banana","cherry","orange","kiwi","melon","mango")
print(thislist[1])
print(thislist[-1])
print(thislist[2:5])
print(thislist[:4])
print(thislist[-4:-1])
# Out:
# banana
# mango
# ('cherry', 'orange', 'kiwi')
# ('apple', 'banana', 'cherry', 'orange')
# ('orange', 'kiwi', 'melon')

# %%
thislist=["apple","banana","cherry"]
thislist.append("orange")
print(thislist)
thislist.insert(1,"orange")
print(thislist)
thislist.remove("banana")
print(thislist)
for x in thislist:
  print(x)
  for i in range(len(thislist)):
    print(thislist[i])
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'orange', 'banana', 'cherry', 'orange']
# ['apple', 'orange', 'cherry', 'orange']
# apple
# apple
# orange
# cherry
# orange
# orange
# apple
# orange
# cherry
# orange
# cherry
# apple
# orange
# cherry
# orange
# orange
# apple
# orange
# cherry
# orange
